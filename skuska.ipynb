# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


def show(image, dpi):
    plt.figure(dpi=dpi)
    plt.imshow(image, cmap='gray')
    plt.show()

# %%
img_name = 'img1.jpg'
img = cv.imread(img_name)
# img = cv.resize(img, (img.shape[1]//2, img.shape[0]//2))
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
# # img = cv.blur(img, (8, 8))
img_gray = cv.medianBlur(img_gray, 5)
# # img = cv.GaussianBlur(img, (5, 5), 10)

circles = cv.HoughCircles(img_gray, cv.HOUGH_GRADIENT, 1, 80,
                          param1=90, param2=35, minRadius=20, maxRadius=100)

circles = np.uint16(np.around(circles))
for i in circles[0, :]:
    # draw the outer circle
    cv.circle(img, (i[0], i[1]), i[2], (0, 255, 0), 2)
    # draw the center of the circle
    cv.circle(img, (i[0], i[1]), 2, (0, 0, 255), 3)

print(len(circles[0]))
show(img, 150)
cv.imwrite('result-' + img_name, img)
# Out:
# 40
# True

# %% [markdown]
# ked viem ze je to pohlad z predu - dal by sa v kazdej kruznici len spravit jednoduchy haar filter prava lava polka, to by fungovalo na prvom obrazku
#
# ked je to nejak random - mohol by sa hodit template matching - spravim si template pre oko napr to je celkom vyrazne a to hladat v kruznici
